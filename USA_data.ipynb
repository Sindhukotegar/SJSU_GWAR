# %%
import numpy as np
import pandas as pd

# %%
t1 = pd.read_excel('table1.xlsx', header=4)

# %%
t1.shape
# Out:
# (54, 57)

# %%
# First, let's calculate the total number of missing values across the entire dataframe
total_missing_values = t1.isnull().sum().sum()

# Now, we calculate the total number of elements across the dataframe
total_elements = t1.size

# Finally, calculate the percentage of missing values
total_percentage_missing = (total_missing_values / total_elements) * 100
total_percentage_missing
# Out:
# 3.6712150747238463

# %%
t1
# Out:
#                                                 State         1970  \
# 0                                             Alabama   102.646851
# 1                                              Alaska    11.348910
# 2                                             Arizona    24.906189
# 3                                            Arkansas    36.178889
# 4                                          California   294.372200
# 5                                            Colorado    43.017559
# 6                                         Connecticut    47.831994
# 7                                            Delaware    16.072307
# 8                                District of Columbia    13.641821
# 9                                             Florida   104.354245
# 10                                            Georgia    73.527753
# 11                                             Hawaii    13.931049
# 12                                              Idaho    10.249784
# ...

# %%
t1 = t1.dropna()

# Convert data types where applicable, using .loc to avoid SettingWithCopyWarning
for col in t1.columns[1:]:  # Assuming the first column is non-numeric (State names)
    t1.loc[:, col] = pd.to_numeric(t1[col], errors='coerce')
#t1 = t1.drop(t1.columns[-1], axis=1)
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3513819483.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, col] = pd.to_numeric(t1[col], errors='coerce')

# %%
t1
# Out:
#                    State         1970         1971         1972         1973  \
# 0                Alabama   102.646851    98.461114   104.932504   109.563135
# 1                 Alaska    11.348910    12.636423    13.420588    12.490564
# 2                Arizona    24.906189    26.998731    30.179241    34.448720
# 3               Arkansas    36.178889    35.091287    37.189109    40.829866
# 4             California   294.372200   305.833367   312.722261   329.285277
# 5               Colorado    43.017559    43.591690    47.467615    51.067649
# 6            Connecticut    47.831994    45.894756    47.215575    48.576991
# 7               Delaware    16.072307    15.929520    16.013802    17.243519
# 8   District of Columbia    13.641821    11.877081    11.305789    11.850216
# 9                Florida   104.354245   111.502511   121.679521   132.240486
# 10               Georgia    73.527753    79.568031    86.759904    93.106091
# ...

# %%
# Convert the decimal fractions to percentages
t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'] * 100
t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'] * 100
t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'].astype(str) + '%'
t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'].astype(str) + '%'
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:4: SettingWithCopyWarning:
# ...

# %%
# Define the new column names with a list comprehension
new_column_names = ['State'] + [f'CO2_Emissions_{year}' for year in range(1970, 2022)] + ['CO2Change_Percent_1970_2021', 'CO2Change_Absolute_1970_2021', 'CO2Change_Percent_2019_2021', 'CO2Change_Absolute_2019_2021']

# Rename the columns
t1.columns = new_column_names

# %%
t1
# Out:
#                    State  CO2_Emissions_1970  CO2_Emissions_1971  \
# 0                Alabama          102.646851           98.461114
# 1                 Alaska           11.348910           12.636423
# 2                Arizona           24.906189           26.998731
# 3               Arkansas           36.178889           35.091287
# 4             California          294.372200          305.833367
# 5               Colorado           43.017559           43.591690
# 6            Connecticut           47.831994           45.894756
# 7               Delaware           16.072307           15.929520
# 8   District of Columbia           13.641821           11.877081
# 9                Florida          104.354245          111.502511
# 10               Georgia           73.527753           79.568031
# 11                Hawaii           13.931049           15.055764
# 12                 Idaho           10.249784           11.068447
# ...

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         52 non-null     object
#  1   CO2_Emissions_1970            52 non-null     float64
#  2   CO2_Emissions_1971            52 non-null     float64
#  3   CO2_Emissions_1972            52 non-null     float64
#  4   CO2_Emissions_1973            52 non-null     float64
#  5   CO2_Emissions_1974            52 non-null     float64
#  6   CO2_Emissions_1975            52 non-null     float64
#  7   CO2_Emissions_1976            52 non-null     float64
#  8   CO2_Emissions_1977            52 non-null     float64
#  9   CO2_Emissions_1978            52 non-null     float64
#  10  CO2_Emissions_1979            52 non-null     float64
#  11  CO2_Emissions_1980            52 non-null     float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Selecting the columns to scale, which in your case are the emission columns from 1970 to 2021
columns_to_scale = [col for col in t1.columns if 'CO2_Emissions' in col]

# Initialize the Min-Max Scaler
scaler = MinMaxScaler()

# Fit the scaler to the data and transform it with .loc to avoid SettingWithCopyWarning
t1.loc[:, columns_to_scale] = scaler.fit_transform(t1[columns_to_scale])
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/1110697404.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, columns_to_scale] = scaler.fit_transform(t1[columns_to_scale])

# %%
t1
# Out:
#                    State  CO2_Emissions_1970  CO2_Emissions_1971  \
# 0                Alabama            0.022852            0.021647
# 1                 Alaska            0.001367            0.001663
# 2                Arizona            0.004558            0.005007
# 3               Arkansas            0.007211            0.006892
# 4             California            0.067970            0.069934
# 5               Colorado            0.008820            0.008871
# 6            Connecticut            0.009953            0.009407
# 7               Delaware            0.002479            0.002430
# 8   District of Columbia            0.001907            0.001486
# 9                Florida            0.023254            0.024684
# 10               Georgia            0.016000            0.017248
# 11                Hawaii            0.001975            0.002226
# 12                 Idaho            0.001109            0.001298
# ...

# %%
t1.to_excel('t1_norm.xlsx',index=False)

# %% [markdown]
# ###table 4

# %%
t4 = pd.read_excel('table4.xlsx', header=5)

# %%
t4.shape
# Out:
# (54, 57)

# %%
# First, let's calculate the total number of missing values across the entire dataframe
total_missing_values = t4.isnull().sum().sum()

# Now, we calculate the total number of elements across the dataframe
total_elements = t4.size

# Finally, calculate the percentage of missing values
total_percentage_missing = (total_missing_values / total_elements) * 100
total_percentage_missing
# Out:
# 3.6387264457439894

# %%
t4 = t4.dropna()

# Convert data types where applicable, using .loc to avoid SettingWithCopyWarning
for col in t4.columns[1:]:  # Assuming the first column is non-numeric (State names)
    t4.loc[:, col] = pd.to_numeric(t4[col], errors='coerce')

# %%
t4
# Out:
#                    State       1970       1971       1972       1973  \
# 0                Alabama  29.744089  28.155881  29.650326  30.604228
# 1                 Alaska  37.331940  39.988680  41.421568  37.735844
# 2                Arizona  13.898543  14.239837  15.029503  16.218795
# 3               Arkansas  18.726133  17.794770  18.419569  19.829950
# 4             California  14.713460  15.031621  15.191754  15.778680
# 5               Colorado  19.351129  18.920004  19.737054  20.459795
# 6            Connecticut  15.729034  14.993386  15.384677  15.833439
# 7               Delaware  29.169341  28.193840  27.947299  29.833077
# 8   District of Columbia  18.044736  15.836108  15.236913  16.210966
# 9                Florida  15.238646  15.577328  16.200176  16.709690
# 10               Georgia  15.960007  16.886254  18.041153  18.962544
# 11                Hawaii  17.998772  18.772773  18.714102  18.722034
# 12                 Idaho  14.275465  14.977601  15.261294  15.290322
# ...

# %%
# Convert the decimal fractions to percentages
t4.loc[:, 'Percent'] = t4.loc[:, 'Percent'] * 100
t4.loc[:, 'Percent.1'] = t4.loc[:, 'Percent.1'] * 100
t4.loc[:, 'Percent'] = t4.loc[:, 'Percent'].astype(str) + '%'
t4.loc[:, 'Percent.1'] = t4.loc[:, 'Percent.1'].astype(str) + '%'

# %%
# Define the new column names with a list comprehension
new_column_names = ['State'] + [f'PerCapita_CO2Emissions_{year}' for year in range(1970, 2022)] + ['PerCapita_CO2Change_Percent_1970_2021', 'PerCapita_CO2Change_Absolute_1970_2021', 'PerCapita_CO2Change_Percent_2019_2021', 'PerCapita_CO2Change_Absolute_2019_2021']

# Rename the columns
t4.columns = new_column_names

# %%
t4
# Out:
#                    State  PerCapita_CO2Emissions_1970  \
# 0                Alabama                    29.744089
# 1                 Alaska                    37.331940
# 2                Arizona                    13.898543
# 3               Arkansas                    18.726133
# 4             California                    14.713460
# 5               Colorado                    19.351129
# 6            Connecticut                    15.729034
# 7               Delaware                    29.169341
# 8   District of Columbia                    18.044736
# 9                Florida                    15.238646
# 10               Georgia                    15.960007
# 11                Hawaii                    17.998772
# 12                 Idaho                    14.275465
# 13              Illinois                    22.215391
# 14               Indiana                    33.051173
# 15                  Iowa                    18.882400
# ...

# %%
t4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   52 non-null     object
#  1   PerCapita_CO2Emissions_1970             52 non-null     float64
#  2   PerCapita_CO2Emissions_1971             52 non-null     float64
#  3   PerCapita_CO2Emissions_1972             52 non-null     float64
#  4   PerCapita_CO2Emissions_1973             52 non-null     float64
#  5   PerCapita_CO2Emissions_1974             52 non-null     float64
#  6   PerCapita_CO2Emissions_1975             52 non-null     float64
#  7   PerCapita_CO2Emissions_1976             52 non-null     float64
#  8   PerCapita_CO2Emissions_1977             52 non-null     float64
#  9   PerCapita_CO2Emissions_1978             52 non-null     float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Selecting the columns to scale, which in your case are the emission columns from 1970 to 2021
columns_to_scale = [col for col in t4.columns if 'PerCapita_CO2Emissions' in col]

# Initialize the Min-Max Scaler
scaler = MinMaxScaler()

# Fit the scaler to the data and transform it with .loc to avoid SettingWithCopyWarning
t4.loc[:, columns_to_scale] = scaler.fit_transform(t4[columns_to_scale])

# %%
t4
# Out:
#                    State  PerCapita_CO2Emissions_1970  \
# 0                Alabama                     0.403602
# 1                 Alaska                     0.578143
# 2                Arizona                     0.039114
# 3               Arkansas                     0.150161
# 4             California                     0.057859
# 5               Colorado                     0.164537
# 6            Connecticut                     0.081220
# 7               Delaware                     0.390382
# 8   District of Columbia                     0.134487
# 9                Florida                     0.069939
# 10               Georgia                     0.086533
# 11                Hawaii                     0.133429
# 12                 Idaho                     0.047784
# 13              Illinois                     0.230423
# 14               Indiana                     0.479674
# 15                  Iowa                     0.153755
# ...

# %%
t4.to_excel('t4_norm.xlsx',index=False)

# %% [markdown]
# ###Table 6

# %%
t6 = pd.read_excel('table6.xlsx', header=5)

# %%
t6
# Out:
#                                                 State       1970       1971  \
# 0                                             Alabama  69.928878  68.183581
# 1                                              Alaska  62.343287  62.879663
# 2                                             Arizona  50.310654  50.948020
# 3                                            Arkansas  52.658995  53.361689
# 4                                          California  54.900121  55.168490
# 5                                            Colorado  62.764081  62.219534
# 6                                         Connecticut  65.706718  61.393395
# 7                                            Delaware  71.372205  70.660940
# 8                                District of Columbia  73.999168  72.166441
# 9                                             Florida  65.879581  66.142469
# 10                                            Georgia  61.902626  62.247726
# ...

# %%
t6.shape
# Out:
# (54, 57)

# %%
# First, let's calculate the total number of missing values across the entire dataframe
total_missing_values = t6.isnull().sum().sum()

# Now, we calculate the total number of elements across the dataframe
total_elements = t6.size

# Finally, calculate the percentage of missing values
total_percentage_missing = (total_missing_values / total_elements) * 100
total_percentage_missing
# Out:
# 3.6387264457439894

# %%
t6 = t6.dropna()

# Convert data types where applicable, using .loc to avoid SettingWithCopyWarning
for col in t6.columns[1:]:  # Assuming the first column is non-numeric (State names)
    t6.loc[:, col] = pd.to_numeric(t6[col], errors='coerce')
#t6 = t6.drop(t1.columns[-1], axis=1)
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2344149450.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t6.loc[:, col] = pd.to_numeric(t6[col], errors='coerce')

# %%
t6
# Out:
#                    State       1970       1971       1972       1973  \
# 0                Alabama  69.928878  68.183581  68.722082  68.294613
# 1                 Alaska  62.343287  62.879663  62.602742  63.415147
# 2                Arizona  50.310654  50.948020  51.614033  53.731172
# 3               Arkansas  52.658995  53.361689  54.460253  53.427967
# 4             California  54.900121  55.168490  55.922621  56.275816
# 5               Colorado  62.764081  62.219534  62.888922  63.560299
# 6            Connecticut  65.706718  61.393395  60.460236  63.743560
# 7               Delaware  71.372205  70.660940  69.514004  69.709088
# 8   District of Columbia  73.999168  72.166441  71.521227  71.905778
# 9                Florida  65.879581  66.142469  66.918393  65.576743
# 10               Georgia  61.902626  62.247726  63.270991  63.113403
# 11                Hawaii  70.735016  71.127464  71.060668  71.111545
# 12                 Idaho  41.290315  42.220841  41.975904  41.944784
# ...

# %%
# Convert the decimal fractions to percentages
t6.loc[:, 'Percent'] = t6.loc[:, 'Percent'] * 100
t6.loc[:, 'Percent.1'] = t6.loc[:, 'Percent.1'] * 100
t6.loc[:, 'Percent'] = t6.loc[:, 'Percent'].astype(str) + '%'
t6.loc[:, 'Percent.1'] = t6.loc[:, 'Percent.1'].astype(str) + '%'
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2070349248.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t6.loc[:, 'Percent'] = t6.loc[:, 'Percent'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2070349248.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t6.loc[:, 'Percent.1'] = t6.loc[:, 'Percent.1'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2070349248.py:4: SettingWithCopyWarning:
# ...

# %%
# Define the new column names with a list comprehension
new_column_names = ['State'] + [f'CarbonIntensity_Energy{year}' for year in range(1970, 2022)] + ['CO2_EnergyIntensityChange_Percent_1970_2021', 'CO2_EnergyIntensityChange_Absolute_1970_2021', 'CO2_EnergyIntensityChange_Percent_2019_2021', 'CO2_EnergyIntensityChange_Absolute_2019_2021']

# Rename the columns
t6.columns = new_column_names

# %%
t6
# Out:
#                    State  CarbonIntensity_Energy1970  \
# 0                Alabama                   69.928878
# 1                 Alaska                   62.343287
# 2                Arizona                   50.310654
# 3               Arkansas                   52.658995
# 4             California                   54.900121
# 5               Colorado                   62.764081
# 6            Connecticut                   65.706718
# 7               Delaware                   71.372205
# 8   District of Columbia                   73.999168
# 9                Florida                   65.879581
# 10               Georgia                   61.902626
# 11                Hawaii                   70.735016
# 12                 Idaho                   41.290315
# 13              Illinois                   67.189260
# 14               Indiana                   74.266845
# 15                  Iowa                   63.260838
# 16                Kansas                   57.270398
# ...

# %%
t6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 57 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         52 non-null     object
#  1   CarbonIntensity_Energy1970                    52 non-null     float64
#  2   CarbonIntensity_Energy1971                    52 non-null     float64
#  3   CarbonIntensity_Energy1972                    52 non-null     float64
#  4   CarbonIntensity_Energy1973                    52 non-null     float64
#  5   CarbonIntensity_Energy1974                    52 non-null     float64
#  6   CarbonIntensity_Energy1975                    52 non-null     float64
#  7   CarbonIntensity_Energy1976                    52 non-null     float64
#  8   CarbonIntensity_Energy1977                    52 non-null     float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Selecting the columns to scale, which in your case are the emission columns from 1970 to 2021
columns_to_scale = [col for col in t6.columns if 'CarbonIntensity_Energy' in col]

# Initialize the Min-Max Scaler
scaler = MinMaxScaler()

# Fit the scaler to the data and transform it with .loc to avoid SettingWithCopyWarning
t6.loc[:, columns_to_scale] = scaler.fit_transform(t6[columns_to_scale])
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2504513940.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t6.loc[:, columns_to_scale] = scaler.fit_transform(t6[columns_to_scale])

# %%
t6
# Out:
#                    State  CarbonIntensity_Energy1970  \
# 0                Alabama                    0.815530
# 1                 Alaska                    0.661033
# 2                Arizona                    0.415963
# 3               Arkansas                    0.463792
# 4             California                    0.509437
# 5               Colorado                    0.669604
# 6            Connecticut                    0.729537
# 7               Delaware                    0.844926
# 8   District of Columbia                    0.898430
# 9                Florida                    0.733057
# 10               Georgia                    0.652058
# 11                Hawaii                    0.831949
# 12                 Idaho                    0.232244
# 13              Illinois                    0.759732
# 14               Indiana                    0.903882
# 15                  Iowa                    0.679721
# 16                Kansas                    0.557713
# ...

# %%
t6.to_excel('t6_norm.xlsx',index=False)

# %% [markdown]
# ###Table7

# %%
t7 = pd.read_excel('table7.xlsx', header=5)

# %%
t7
# Out:
#                                                 State         1997  \
# 0                                             Alabama   776.145415
# 1                                              Alaska   976.655518
# 2                                             Arizona   364.052287
# 3                                            Arkansas   688.243839
# 4                                          California   289.475519
# 5                                            Colorado   433.944499
# 6                                         Connecticut   266.505003
# 7                                            Delaware   437.429523
# 8                                District of Columbia   145.823737
# 9                                             Florida   423.557048
# 10                                            Georgia   492.665590
# 11                                             Hawaii   334.899058
# 12                                              Idaho   465.377450
# ...

# %%
t7.shape
# Out:
# (54, 30)

# %%
# First, let's calculate the total number of missing values across the entire dataframe
total_missing_values = t7.isnull().sum().sum()

# Now, we calculate the total number of elements across the dataframe
total_elements = t7.size

# Finally, calculate the percentage of missing values
total_percentage_missing = (total_missing_values / total_elements) * 100
total_percentage_missing
# Out:
# 3.580246913580247

# %%
t7 = t7.dropna()

# Convert data types where applicable, using .loc to avoid SettingWithCopyWarning
for col in t7.columns[1:]:  # Assuming the first column is non-numeric (State names)
    t7.loc[:, col] = pd.to_numeric(t7[col], errors='coerce')
#t1 = t1.drop(t1.columns[-1], axis=1)
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/2660624738.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t7.loc[:, col] = pd.to_numeric(t7[col], errors='coerce')

# %%
# Convert the decimal fractions to percentages
t7.loc[:, 'Percent'] = t7.loc[:, 'Percent'] * 100
t7.loc[:, 'Percent.1'] = t7.loc[:, 'Percent.1'] * 100
t7.loc[:, 'Percent'] = t7.loc[:, 'Percent'].astype(str) + '%'
t7.loc[:, 'Percent.1'] = t7.loc[:, 'Percent.1'].astype(str) + '%'
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/692191229.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t7.loc[:, 'Percent'] = t7.loc[:, 'Percent'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/692191229.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t7.loc[:, 'Percent.1'] = t7.loc[:, 'Percent.1'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/692191229.py:4: SettingWithCopyWarning:
# ...

# %%
t7
# Out:
#                    State         1997         1998         1999         2000  \
# 0                Alabama   776.145415   763.941446   756.415596   782.314034
# 1                 Alaska   976.655518  1027.981331  1056.026499  1105.836558
# 2                Arizona   364.052287   355.818506   347.858289   354.239675
# 3               Arkansas   688.243839   702.908227   690.959776   723.776878
# 4             California   289.475519   275.659040   259.899515   246.279211
# 5               Colorado   433.944499   410.333378   395.110680   382.676429
# 6            Connecticut   266.505003   238.627399   211.455665   195.349513
# 7               Delaware   437.429523   394.304233   373.039571   386.554045
# 8   District of Columbia   145.823737   141.266807   138.123440   142.236885
# 9                Florida   423.557048   414.184838   398.805679   401.533022
# 10               Georgia   492.665590   464.563545   443.073627   451.454081
# ...

# %%
# Define the new column names with a list comprehension
new_column_names = ['State'] + [f'CO2Intensity_Economy_{year}' for year in range(1997, 2022)] + ['CO2IntensityChange_Economy_Percent_1997-2021', 'CO2IntensityChange_Economy_Absolute_1997-2021', 'CO2IntensityChange_Economy_Percent_2020-2021', 'CO2IntensityChange_Economy_Absolute_2020-2021']

# Rename the columns
t7.columns = new_column_names

# %%
t7
# Out:
#                    State  CO2Intensity_Economy_1997  \
# 0                Alabama                 776.145415
# 1                 Alaska                 976.655518
# 2                Arizona                 364.052287
# 3               Arkansas                 688.243839
# 4             California                 289.475519
# 5               Colorado                 433.944499
# 6            Connecticut                 266.505003
# 7               Delaware                 437.429523
# 8   District of Columbia                 145.823737
# 9                Florida                 423.557048
# 10               Georgia                 492.665590
# 11                Hawaii                 334.899058
# 12                 Idaho                 465.377450
# 13              Illinois                 399.055291
# 14               Indiana                 886.104395
# 15                  Iowa                 687.425897
# 16                Kansas                 667.946632
# ...

# %%
t7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 30 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   State                                          52 non-null     object
#  1   CO2Intensity_Economy_1997                      52 non-null     float64
#  2   CO2Intensity_Economy_1998                      52 non-null     float64
#  3   CO2Intensity_Economy_1999                      52 non-null     float64
#  4   CO2Intensity_Economy_2000                      52 non-null     float64
#  5   CO2Intensity_Economy_2001                      52 non-null     float64
#  6   CO2Intensity_Economy_2002                      52 non-null     float64
#  7   CO2Intensity_Economy_2003                      52 non-null     float64
#  8   CO2Intensity_Economy_2004                      52 non-null     float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Selecting the columns to scale, which in your case are the emission columns from 1970 to 2021
columns_to_scale = [col for col in t7.columns if 'CO2Intensity_Economy' in col]

# Initialize the Min-Max Scaler
scaler = MinMaxScaler()

# Fit the scaler to the data and transform it with .loc to avoid SettingWithCopyWarning
t7.loc[:, columns_to_scale] = scaler.fit_transform(t7[columns_to_scale])
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/561081642.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t7.loc[:, columns_to_scale] = scaler.fit_transform(t7[columns_to_scale])

# %%
t7
# Out:
#                    State  CO2Intensity_Economy_1997  \
# 0                Alabama                   0.521151
# 1                 Alaska                   0.686934
# 2                Arizona                   0.180432
# 3               Arkansas                   0.448474
# 4             California                   0.118772
# 5               Colorado                   0.238219
# 6            Connecticut                   0.099780
# 7               Delaware                   0.241100
# 8   District of Columbia                   0.000000
# 9                Florida                   0.229631
# 10               Georgia                   0.286770
# 11                Hawaii                   0.156328
# 12                 Idaho                   0.264208
# 13              Illinois                   0.209372
# 14               Indiana                   0.612066
# 15                  Iowa                   0.447798
# 16                Kansas                   0.431692
# ...

# %%
t7.to_excel('t7_norm.xlsx',index=False)

# %% [markdown]
# ###Visualizations

# %%
t1 = pd.read_excel('table1.xlsx', header=4)

# %%
t1
# Out:
#                                                 State         1970  \
# 0                                             Alabama   102.646851
# 1                                              Alaska    11.348910
# 2                                             Arizona    24.906189
# 3                                            Arkansas    36.178889
# 4                                          California   294.372200
# 5                                            Colorado    43.017559
# 6                                         Connecticut    47.831994
# 7                                            Delaware    16.072307
# 8                                District of Columbia    13.641821
# 9                                             Florida   104.354245
# 10                                            Georgia    73.527753
# 11                                             Hawaii    13.931049
# 12                                              Idaho    10.249784
# ...

# %%
t1 = t1.dropna()

# Convert data types where applicable, using .loc to avoid SettingWithCopyWarning
for col in t1.columns[1:]:  # Assuming the first column is non-numeric (State names)
    t1.loc[:, col] = pd.to_numeric(t1[col], errors='coerce')
#t1 = t1.drop(t1.columns[-1], axis=1)
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3513819483.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, col] = pd.to_numeric(t1[col], errors='coerce')

# %%
# Convert the decimal fractions to percentages
t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'] * 100
t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'] * 100
t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'].astype(str) + '%'
t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'].astype(str) + '%'
# Out:
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, 'Percent'] = t1.loc[:, 'Percent'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1.loc[:, 'Percent.1'] = t1.loc[:, 'Percent.1'] * 100
# /var/folders/tz/3gc62l0518x3dtgsh9grl8540000gn/T/ipykernel_62732/3771933938.py:4: SettingWithCopyWarning:
# ...

# %%
# Define the new column names with a list comprehension
new_column_names = ['State'] + [f'CO2_Emissions_{year}' for year in range(1970, 2022)] + ['CO2Change_Percent_1970_2021', 'CO2Change_Absolute_1970_2021', 'CO2Change_Percent_2019_2021', 'CO2Change_Absolute_2019_2021']

# Rename the columns
t1.columns = new_column_names

# %%
t1
# Out:
#                    State  CO2_Emissions_1970  CO2_Emissions_1971  \
# 0                Alabama          102.646851           98.461114
# 1                 Alaska           11.348910           12.636423
# 2                Arizona           24.906189           26.998731
# 3               Arkansas           36.178889           35.091287
# 4             California          294.372200          305.833367
# 5               Colorado           43.017559           43.591690
# 6            Connecticut           47.831994           45.894756
# 7               Delaware           16.072307           15.929520
# 8   District of Columbia           13.641821           11.877081
# 9                Florida          104.354245          111.502511
# 10               Georgia           73.527753           79.568031
# 11                Hawaii           13.931049           15.055764
# 12                 Idaho           10.249784           11.068447
# ...

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         52 non-null     object
#  1   CO2_Emissions_1970            52 non-null     float64
#  2   CO2_Emissions_1971            52 non-null     float64
#  3   CO2_Emissions_1972            52 non-null     float64
#  4   CO2_Emissions_1973            52 non-null     float64
#  5   CO2_Emissions_1974            52 non-null     float64
#  6   CO2_Emissions_1975            52 non-null     float64
#  7   CO2_Emissions_1976            52 non-null     float64
#  8   CO2_Emissions_1977            52 non-null     float64
#  9   CO2_Emissions_1978            52 non-null     float64
#  10  CO2_Emissions_1979            52 non-null     float64
#  11  CO2_Emissions_1980            52 non-null     float64
# ...

# %%
import matplotlib.pyplot as plt

columns = [col for col in t1.columns if 'CO2_Emissions' in col]

# Set the 'State' column as the index
data_selected = t1.set_index('State')[columns]

states_to_plot = ['California', 'Texas', 'New York']

# Create a line plot
plt.figure(figsize=(14, 7))
for state in states_to_plot:
    plt.plot(data_selected.columns, data_selected.loc[state], label=state)

plt.title('Trends in CO2 Emissions (1970-2021)')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (as % of national total)')
plt.xticks(rotation=45)
plt.legend(title='State')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Select the row for the total U.S. emissions which is labeled "Total of states"
total_us_data = t1[t1['State'] == 'Total of states']

# Select the columns related to CO2 emissions
columns = [col for col in t1.columns if 'CO2_Emissions' in col]

# Create a line plot for the total U.S. emissions
plt.figure(figsize=(14, 7))
plt.plot(columns, total_us_data[columns].values.flatten(), label='Total of states', marker='o')

plt.title('Trends in CO2 Emissions for the Total U.S. (1970-2021)')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (as % of national total)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
